# %% [markdown]
# # External Data Sources
#
# The package [Pandas DataReader](https://pydata.github.io/pandas-datareader/stable/) lets us pull financial data directly from the web. There's not a lot to add about it. Just read [the docs](https://pydata.github.io/pandas-datareader/stable/) if you want to know more about it.

# %%
import pandas as pd
import numpy as np

# %%
import pandas_datareader.data as web

# %%
start = pd.Timestamp('2017-01-01')
end = pd.Timestamp('2017-02-01')

# %% [markdown]
# **S&P 500**

# %%
web.DataReader('^SPX', 'stooq', start, end)
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2018-04-18  2710.11  2717.49  2703.63  2708.64  4.932002e+08
# 2018-04-17  2692.74  2713.34  2692.05  2706.39  4.961728e+08
# 2018-04-16  2670.10  2686.49  2665.16  2677.84  5.101475e+08
# 2018-04-13  2676.90  2680.26  2645.05  2656.30  4.893403e+08
# 2018-04-12  2653.83  2674.72  2653.83  2663.99  5.147257e+08
# 2018-04-11  2643.89  2661.43  2639.25  2642.19  4.726213e+08
# 2018-04-10  2638.41  2665.45  2635.78  2656.87  5.960542e+08
# 2018-04-09  2617.18  2653.55  2610.79  2613.16  5.645807e+08
# 2018-04-06  2645.82  2656.88  2586.27  2604.47  6.369535e+08
# 2018-04-05  2657.36  2672.08  2649.58  2662.84  5.304348e+08
# 2018-04-04  2584.04  2649.86  2573.61  2644.69  6.241035e+08
# 2018-04-03  2592.17  2619.14  2575.49  2614.45  6.310170e+08
# 2018-04-02  2633.45  2638.30  2553.80  2581.88  7.136920e+08
# 2018-03-29  2614.41  2659.07  2609.72  2640.87  7.460317e+08
# ...

# %% [markdown]
# **Stocks**

# %%
web.DataReader(('MSFT', 'AAPL', 'GOOG', 'AMZN', 'FB'), 'morningstar', start, end)
# Out:
#                     Close      High       Low     Open    Volume
# Symbol Date
# MSFT   2017-01-02   62.14   62.1400   62.1400   62.140         0
#        2017-01-03   62.58   62.8400   62.1250   62.790  20694101
#        2017-01-04   62.30   62.7500   62.1200   62.480  21339969
#        2017-01-05   62.30   62.6600   62.0300   62.190  24875968
#        2017-01-06   62.84   63.1500   62.0400   62.300  19922919
#        2017-01-09   62.64   63.0800   62.5400   62.760  20382730
#        2017-01-10   62.62   63.0700   62.2800   62.730  18593004
#        2017-01-11   63.19   63.2300   62.4300   62.610  21517335
#        2017-01-12   62.61   63.4000   61.9500   63.060  20968223
#        2017-01-13   62.70   62.8650   62.3500   62.620  19422310
#        2017-01-16   62.70   62.7000   62.7000   62.700         0
#        2017-01-17   62.53   62.7000   62.0300   62.680  20663983
#        2017-01-18   62.50   62.7000   62.1200   62.670  19670102
# ...
